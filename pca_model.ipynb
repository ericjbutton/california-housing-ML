# %%
import pandas as pd
from pathlib import Path

# %% [markdown]
# # Data Cleaning and Preprocessing

# %%
# Reading in file
file_path = Path("housing.csv")
cal_housing_df = pd.read_csv(file_path)
cal_housing_df.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
# 7    -122.25     37.84                52.0       3104.0           687.0
# 8    -122.26     37.84                42.0       2555.0           665.0
# 9    -122.25     37.84                52.0       3549.0           707.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
# 5       413.0       193.0         4.0368            269700.0        NEAR BAY
# 6      1094.0       514.0         3.6591            299200.0        NEAR BAY
# 7      1157.0       647.0         3.1200            241400.0        NEAR BAY
# 8      1206.0       595.0         2.0804            226700.0        NEAR BAY
# 9      1551.0       714.0         3.6912            261100.0        NEAR BAY

# %%
#Listing data types
cal_housing_df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
# Find null values
for column in cal_housing_df.columns:
    print(f"Column {column} has {cal_housing_df[column].isnull().sum()} null values")
# Out:
# Column longitude has 0 null values
# Column latitude has 0 null values
# Column housing_median_age has 0 null values
# Column total_rooms has 0 null values
# Column total_bedrooms has 207 null values
# Column population has 0 null values
# Column households has 0 null values
# Column median_income has 0 null values
# Column median_house_value has 0 null values
# Column ocean_proximity has 0 null values

# %%
# Dropping null values
cal_housing_df.dropna(axis=0, how='any', inplace=True)
cal_housing_df.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
# 7    -122.25     37.84                52.0       3104.0           687.0
# 8    -122.26     37.84                42.0       2555.0           665.0
# 9    -122.25     37.84                52.0       3549.0           707.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
# 5       413.0       193.0         4.0368            269700.0        NEAR BAY
# 6      1094.0       514.0         3.6591            299200.0        NEAR BAY
# 7      1157.0       647.0         3.1200            241400.0        NEAR BAY
# 8      1206.0       595.0         2.0804            226700.0        NEAR BAY
# 9      1551.0       714.0         3.6912            261100.0        NEAR BAY

# %%
# Identifying values to label encode
cal_housing_df['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
#Label Encoding
ocean_proximity_dict = {'NEAR BAY': 0, '<1H OCEAN': 1, 'NEAR OCEAN':2, 'ISLAND':3, 'INLAND':4}
encoded_cal_housing_df = cal_housing_df.replace({'ocean_proximity': ocean_proximity_dict })
encoded_cal_housing_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#        ocean_proximity
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 20635                4
# 20636                4
# 20637                4
# 20638                4
# 20639                4
#
# [20433 rows x 10 columns]

# %%
#Setting X and y variables
X = encoded_cal_housing_df.drop(['median_house_value'], axis = 1)
y = encoded_cal_housing_df['median_house_value']

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  ocean_proximity
# 0           322.0       126.0         8.3252                0
# 1          2401.0      1138.0         8.3014                0
# 2           496.0       177.0         7.2574                0
# 3           558.0       219.0         5.6431                0
# 4           565.0       259.0         3.8462                0
# ...           ...         ...            ...              ...
# 20635       845.0       330.0         1.5603                4
# 20636       356.0       114.0         2.5568                4
# 20637      1007.0       433.0         1.7000                4
# 20638       741.0       349.0         1.8672                4
# 20639      1387.0       530.0         2.3886                4
#
# [20433 rows x 9 columns]

# %% [markdown]
# # Applying PCA to Reduce Dimensions (9 to 5 Principal Components)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

X_scaled = StandardScaler().fit_transform(X)


# Reducing from 9 to 5 components
pca = PCA(n_components = 5)

X_pca = pca.fit_transform(X_scaled)

# %%
df_X_pca = pd.DataFrame(
    data = X_pca, columns = ["principal component 1",
                             "principal component 2",
                             "principal component 3",
                             "principal component 4",
                             "principal component 5"]
)

df_X_pca.head()
# Out:
#    principal component 1  principal component 2  principal component 3  \
# 0              -2.106982               1.080385               2.633460
# 1               2.922273               1.627345               2.474950
# 2              -1.983816               1.134211               2.726445
# 3              -1.932493               1.202893               2.320466
# 4              -1.789646               1.291039               1.883223
#
#    principal component 4  principal component 5
# 0              -1.317406               0.501316
# 1              -1.535044               0.067326
# 2              -0.334536               0.912172
# 3               0.339983               0.555958
# 4               1.062338               0.201359

# %% [markdown]
# # Training and Fitting Model

# %%
# Training model
from sklearn.model_selection import train_test_split
X = df_X_pca

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

model.fit(X_train, y_train)

training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.583036805186764
# Testing Score: 0.5991138105538574

# %%
import matplotlib.pyplot as plt
plt.scatter(model.predict(X_train), y_train - model.predict(X_train), c="blue", label="Training Data")
plt.scatter(model.predict(X_test), y_test - model.predict(X_test), c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.title("PCA Model Residual Plot")
plt.show()
plt.savefig("Images/pcamodelresidualplot.png")
